# %% [markdown]
# <a href="https://colab.research.google.com/github/JangAY/TugasAkhir_PCD/blob/main/TugasAkhir_PCD_Kelompok4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Salt-and-Pepper Noise Removal by Median-Type Noise Detectors and Detail-Preserving Regularization

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

def add_salt_and_pepper_noise(image, noise_ratio):
    """
    Add salt and pepper noise to an image with the specified noise ratio.
    """
    noisy_image = np.copy(image)
    total_pixels = image.size
    num_noisy = int(total_pixels * noise_ratio)

    # Salt noise
    salt_coords = [
        np.random.randint(0, i - 1, num_noisy // 2) for i in image.shape
    ]
    noisy_image[tuple(salt_coords)] = 255

    # Pepper noise
    pepper_coords = [
        np.random.randint(0, i - 1, num_noisy // 2) for i in image.shape
    ]
    noisy_image[tuple(pepper_coords)] = 0

    return noisy_image

def median_filter(image, kernel_size):
    return cv2.medianBlur(image, kernel_size)

# Placeholder functions for other methods
def psm_filter(image):
    # Implement PSM filter here
    return image

def msm_filter(image):
    # Implement MSM filter here
    return image

def ddbsm_filter(image):
    # Implement DDBSM filter here
    return image

def nasm_filter(image):
    # Implement NASM filter here
    return image

def ism_filter(image):
    # Implement ISM filter here
    return image

def algorithm_i(image):
    # Implement Algorithm I here
    return image

def algorithm_ii(image):
    # Implement Algorithm II here
    return image

def proposed_algorithm(image):
    # Implement the proposed algorithm here
    return image

# Load the image
image_path = "/content/GettyImages.webp"  # Replace with your image path
original_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Add 70% salt-and-pepper noise
noise_ratio = 0.7
noisy_image = add_salt_and_pepper_noise(original_image, noise_ratio)

# Apply different filters
med_filtered = median_filter(noisy_image, 3)
psm_filtered = psm_filter(noisy_image)
msm_filtered = msm_filter(noisy_image)
ddbsm_filtered = ddbsm_filter(noisy_image)
nasm_filtered = nasm_filter(noisy_image)
ism_filtered = ism_filter(noisy_image)
alg_i_filtered = algorithm_i(noisy_image)
alg_ii_filtered = algorithm_ii(noisy_image)
proposed_filtered = proposed_algorithm(noisy_image)

# Plot the results
plt.figure(figsize=(20, 10))

plt.subplot(3, 4, 1)
plt.title("Noisy Image")
plt.imshow(noisy_image, cmap='gray')
plt.axis("off")

plt.subplot(3, 4, 2)
plt.title("MED Filter")
plt.imshow(med_filtered, cmap='gray')
plt.axis("off")

plt.subplot(3, 4, 3)
plt.title("PSM Filter")
plt.imshow(psm_filtered, cmap='gray')
plt.axis("off")

plt.subplot(3, 4, 4)
plt.title("MSM Filter")
plt.imshow(msm_filtered, cmap='gray')
plt.axis("off")

plt.subplot(3, 4, 5)
plt.title("DDBSM Filter")
plt.imshow(ddbsm_filtered, cmap='gray')
plt.axis("off")

plt.subplot(3, 4, 6)
plt.title("NASM Filter")
plt.imshow(nasm_filtered, cmap='gray')
plt.axis("off")

plt.subplot(3, 4, 7)
plt.title("ISM Filter")
plt.imshow(ism_filtered, cmap='gray')
plt.axis("off")

plt.subplot(3, 4, 8)
plt.title("Algorithm I")
plt.imshow(alg_i_filtered, cmap='gray')
plt.axis("off")

plt.subplot(3, 4, 9)
plt.title("Algorithm II")
plt.imshow(alg_ii_filtered, cmap='gray')
plt.axis("off")

plt.subplot(3, 4, 10)
plt.title("Proposed Algorithm")
plt.imshow(proposed_filtered, cmap='gray')
plt.axis("off")

plt.subplot(3, 4, 11)
plt.title("Original Image")
plt.imshow(original_image, cmap='gray')
plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Penjelasan Program Penghapusan Noise pada Gambar
#
# Program ini bertujuan untuk menganalisis berbagai metode dalam menghapus noise "Salt-and-Pepper" dari sebuah gambar, termasuk penggunaan filter median dan beberapa algoritma lainnya. Berikut adalah penjelasan rinci:
#
# ---
#
# ## **1. Penambahan Noise Salt-and-Pepper**
# Fungsi `add_salt_and_pepper_noise` digunakan untuk menambahkan noise pada gambar dengan tingkat 70%. Noise ini terdiri dari piksel putih (salt) dan hitam (pepper) yang tersebar secara acak.
#
# - **Input**:
#   - `image`: Gambar input.
#   - `noise_ratio`: Rasio noise yang ingin ditambahkan (70% pada kasus ini).
# - **Output**: Gambar dengan noise "Salt-and-Pepper".
# - **Langkah Utama**:
#   - Hitung total jumlah piksel yang akan terkena noise.
#   - Tentukan koordinat piksel untuk noise "salt" (warna putih) dan "pepper" (warna hitam).
#   - Terapkan noise pada gambar.
#
# ---
#
# ## **2. Filter yang Digunakan**
# Beberapa filter digunakan untuk memulihkan gambar yang telah tercemar noise, termasuk filter yang sudah diimplementasikan dan placeholder untuk filter yang memerlukan implementasi tambahan:
#
# ### **a. Filter Median (MED Filter)**
# - Fungsi `cv2.medianBlur` digunakan untuk mengurangi noise dengan filter median.
# - Parameter `kernel_size` menentukan ukuran kernel filter.
#
# ### **b. Placeholder Filter**
# Filter berikut belum diimplementasikan secara penuh dalam kode, namun disiapkan untuk pengembangan lebih lanjut:
# - **PSM Filter**
# - **MSM Filter**
# - **DDBSM Filter**
# - **NASM Filter**
# - **ISM Filter**
# - **Algorithm I**
# - **Algorithm II**
# - **Proposed Algorithm**
#
# ---
#
# ## **3. Proses Restorasi**
# Gambar yang telah terpapar noise diproses dengan berbagai filter untuk memperbaiki kualitasnya. Langkah-langkah utama meliputi:
# 1. Memuat gambar asli dalam format grayscale.
# 2. Menambahkan noise dengan rasio 70%.
# 3. Menerapkan setiap filter untuk memulihkan gambar.
#
# ---
#
# ## **4. Visualisasi Hasil**
# Hasil dari tiap filter divisualisasikan menggunakan `matplotlib`. Terdapat 12 subplot yang masing-masing menunjukkan:
#
# 1. **Noisy Image**: Gambar dengan noise Salt-and-Pepper.
# 2. **MED Filter**: Hasil filter median.
# 3. **PSM Filter**: Placeholder.
# 4. **MSM Filter**: Placeholder.
# 5. **DDBSM Filter**: Placeholder.
# 6. **NASM Filter**: Placeholder.
# 7. **ISM Filter**: Placeholder.
# 8. **Algorithm I**: Placeholder.
# 9. **Algorithm II**: Placeholder.
# 10. **Proposed Algorithm**: Placeholder.
# 11. **Original Image**: Gambar asli tanpa noise.
#
# ---
#
# ## **Langkah Selanjutnya**
# Untuk melengkapi program ini, perlu dilakukan implementasi pada filter yang masih berupa placeholder. Setiap filter dapat diimplementasikan berdasarkan metode atau algoritma spesifik yang sesuai dengan tujuan restorasi gambar.
#
# ---
#
# ## **Hasil**
# Setelah menjalankan program:
# - Gambar asli dan gambar dengan noise akan ditampilkan.
# - Efektivitas filter median dapat dianalisis secara visual.
# - Filter lain (placeholder) dapat dikembangkan untuk perbandingan hasil yang lebih lengkap.
